# %%
import sys
sys.path.append('C:/Users/Eric/')

# %%
import pandas as pd
import seaborn_visualizer as sbv
import seaborn as sns

# %% [markdown]
# # Big Five EDA

# %%
df = pd.read_csv('../../data/01-modified-data/big_five_final.csv')
sbv.get_pd_info(df)
sbv.pd_general_plots(df)
# Out:
# ----------------------
# GENERAL:
# ----------------------
# number of rows: 212625
# number of col: 9
# keys: Index(['case_id', 'country', 'age', 'sex', 'agreeable_score',
#        'extraversion_score', 'openness_score', 'conscientiousness_score',
#        'neuroticism_score'],
#       dtype='object') <class 'pandas.core.indexes.base.Index'>
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 212625 entries, 0 to 212624
# Data columns (total 9 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   case_id                  212625 non-null  float64
#  1   country                  212625 non-null  object
#  2   age                      212625 non-null  int64
#  3   sex                      212625 non-null  int64
#  4   agreeable_score          212625 non-null  float64
#  5   extraversion_score       212625 non-null  float64
#  6   openness_score           212625 non-null  float64
#  7   conscientiousness_score  212625 non-null  float64
#  8   neuroticism_score        212625 non-null  float64
# dtypes: float64(6), int64(2), object(1)
# memory usage: 14.6+ MB
# info None
# head    case_id country  age  sex  agreeable_score  extraversion_score  \
# 0      7.0     USA   17    1         0.603333            0.586667
# 1     10.0     USA   18    1         0.610000            0.706667
# 2     18.0     USA   20    1         0.720000            0.730000
# 3     26.0     USA   34    1         0.786667            0.810000
# 4     27.0     USA   24    1         0.573333            0.646667
#
#    openness_score  conscientiousness_score  neuroticism_score
# 0        0.653333                 0.596667           0.623333
# 1        0.886667                 0.590000           0.656667
# 2        0.856667                 0.806667           0.303333
# 3        0.810000                 0.810000           0.510000
# 4        0.770000                 0.926667           0.463333
# TYPES case_id                    float64
# country                     object
# age                          int64
# sex                          int64
# agreeable_score            float64
# extraversion_score         float64
# openness_score             float64
# conscientiousness_score    float64
# neuroticism_score          float64
# dtype: object
# ----------------------
# BASIC STATISTICS:
# ----------------------
#              case_id            age            sex  agreeable_score  \
# count  212625.000000  212625.000000  212625.000000    212625.000000
# mean   165799.147955      25.163405       1.623812         0.698715
# std     96700.278153      10.237499       0.484429         0.094277
# min         4.000000      10.000000       1.000000         0.200000
# 25%     81573.000000      18.000000       1.000000         0.640000
# 50%    165123.000000      21.000000       2.000000         0.706667
# 75%    248929.000000      29.000000       2.000000         0.766667
# max    334158.000000      99.000000       2.000000         0.986667
#
#        extraversion_score  openness_score  conscientiousness_score  \
# count       212625.000000   212625.000000            212625.000000
# mean             0.675318        0.729864                 0.706433
# std              0.109226        0.088581                 0.107443
# min              0.200000        0.276667                 0.206667
# 25%              0.603333        0.670000                 0.633333
# 50%              0.683333        0.730000                 0.710000
# 75%              0.753333        0.793333                 0.783333
# max              0.990000        0.996667                 1.000000
#
#        neuroticism_score
# count      212625.000000
# mean            0.574397
# std             0.126158
# min             0.196667
# 25%             0.483333
# 50%             0.570000
# 75%             0.660000
# max             0.996667
# ----------------------
# CORRELATION MATRIX:
# ----------------------
#                           case_id       age       sex  agreeable_score  \
# case_id                  1.000000 -0.042168 -0.048794         0.035429
# age                     -0.042168  1.000000  0.016561         0.175844
# sex                     -0.048794  0.016561  1.000000         0.237245
# agreeable_score          0.035429  0.175844  0.237245         1.000000
# extraversion_score       0.031448 -0.155381  0.070725         0.055566
# openness_score          -0.087116 -0.000831  0.098819         0.157041
# conscientiousness_score  0.090634  0.261170  0.053846         0.319410
# neuroticism_score       -0.096540 -0.108865  0.195044        -0.177599
#
#                          extraversion_score  openness_score  \
# case_id                            0.031448       -0.087116
# age                               -0.155381       -0.000831
# sex                                0.070725        0.098819
# agreeable_score                    0.055566        0.157041
# extraversion_score                 1.000000        0.235345
# openness_score                     0.235345        1.000000
# conscientiousness_score            0.139155       -0.061381
# neuroticism_score                 -0.423954       -0.030985
#
#                          conscientiousness_score  neuroticism_score
# case_id                                 0.090634          -0.096540
# age                                     0.261170          -0.108865
# sex                                     0.053846           0.195044
# agreeable_score                         0.319410          -0.177599
# extraversion_score                      0.139155          -0.423954
# openness_score                         -0.061381          -0.030985
# conscientiousness_score                 1.000000          -0.456941
# neuroticism_score                      -0.456941           1.000000
